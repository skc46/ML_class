# %%
# !pip install nbconvert

# %%
pip install -U notebook-as-pdf
# Out:
# ...
#
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61085 sha256=b84c3184da00f9e480f33819ef3ddcd3566392d146c93706eb577d15a4c88738
#   Stored in directory: c:\users\shambhu\appdata\local\pip\cache\wheels\80\1a\24\648467ade3a77ed20f35cfd2badd32134e96dd25ca811e64b3
# Successfully built PyPDF2
# ...
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 2.0.0
#     Uninstalling importlib-metadata-2.0.0:
#       Successfully uninstalled importlib-metadata-2.0.0
# ...

# %%
# !pyppeteer-install
# Out:
# [W:pyppeteer.chromium_downloader] start chromium download.
# Download may take a few minutes.
#
# ...
# 100%|##########| 136913619/136913619 [00:45<00:00, 3000798.05it/s]
# [W:pyppeteer.chromium_downloader]
# chromium download done.
# [W:pyppeteer.chromium_downloader] chromium extracted to: C:\Users\shambhu\AppData\Local\pyppeteer\pyppeteer\local-chromium\588429
